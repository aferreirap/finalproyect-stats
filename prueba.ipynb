# %%
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import cv2

def processing(img,height=int,width=int):
    dim = (width,height)
    size =  cv2.resize(img,dim, interpolation=cv2.INTER_LINEAR)
    norm = np.zeros((255, 255))
    norm_img = cv2.normalize(size, norm, 0, 255, cv2.NORM_MINMAX)
    
    return  cv2.GaussianBlur(norm_img, (5, 5), 0)

# %%
def get_images():
    df = pd.DataFrame(columns=['App','Image'])

    app_images = [x for x in os.listdir(('./apps_imgs')) if str(x) != '.DS_Store']

    for image in app_images:
        try: 
            crude  = np.asarray(Image.open(f'./apps_imgs/{image}')) #transforming image to array
            processed_img = processing(crude,255,255) #resizing, normalizing and bluring image
        except IOError:
            pass
        image_name = image[:-4]
        df = df.append({'App' : image_name, 'Image': processed_img} , ignore_index=True)
    return df

# %%
processed_images = get_images()

# %%
img = Image.fromarray(processed_images.iloc[1,1])
img.show()

# %%
app_data_total = pd.read_csv('./Google-Playstore.csv')
app_sample = app_data_total.sample(n=10000,random_state=48)
app_sample.head()
# Out:
#                                App Name  \
# 680082                      2048 - Dark
# 1302179         New Year Countdown 2020
# 2209906  Imágenes de Amistad con Frases
# 187085               ExpoMYS - Demo App
# 566226    TOPZ Frozen Yogurt Metro Deli
#
#                                         App Id       Category  Rating  \
# 680082                com.parthshukla.game2048         Puzzle     4.2
# 1302179        com.giudicelli.newyearcountdown      Lifestyle     0.0
# 2209906   com.cerezapps.Frasesbonitasdeamistad  Communication     0.0
# 187085    air.com.mapyourshow.EXPOMYSMobileApp       Business     0.0
# 566226   com.chownow.topzfrozenyogurtmetrodeli   Food & Drink     0.0
#
#          Rating Count Installs  Minimum Installs  Maximum Installs  Free  \
# 680082           12.0     500+             500.0               855  True
# 1302179           0.0     100+             100.0               137  True
# 2209906           0.0      10+              10.0                40  True
# 187085            0.0     100+             100.0               102  True
# 566226            0.0     100+             100.0               365  True
#
#          Price  ...                                  Developer Website  \
# 680082     0.0  ...                                                NaN
# 1302179    0.0  ...                                                NaN
# 2209906    0.0  ...  https://cerezapps.com/imágenes-de-amistad-con-...
# 187085     0.0  ...                       https://www.mapyourshow.com/
# 566226     0.0  ...                             http://www.chownow.com
#
#                       Developer Email      Released  Last Updated  \
# 680082       parthshukla285@gmail.com   Jul 1, 2020  Jul 09, 2020
# 1302179  patrick.giudicelli@gmail.com  Dec 30, 2017  Nov 26, 2019
# 2209906        contacto@cerezapps.com   Jan 4, 2019  Jan 14, 2019
# 187085        support@mapyourshow.com  Oct 19, 2017  May 21, 2021
# 566226        eng-android@chownow.com   Nov 7, 2016  Feb 19, 2020
#
#         Content Rating                                  Privacy Policy  \
# 680082        Everyone       https://2048-4.flycricket.io/privacy.html
# 1302179       Everyone                                             NaN
# 2209906       Everyone  https://cerezapps.com/politicas-de-privacidad/
# 187085        Everyone   http://www.mapyourshow.com/privacy-policy.cfm
# 566226        Everyone           http://www.chownow.com/privacy-policy
#
#         Ad Supported In App Purchases Editors Choice         Scraped Time
# 680082          True            False          False  2021-06-16 07:19:26
# 1302179         True            False          False  2021-06-15 22:12:27
# 2209906         True            False          False  2021-06-16 11:29:13
# 187085         False            False          False  2021-06-15 23:30:13
# 566226         False            False          False  2021-06-16 05:34:49
#
# [5 rows x 24 columns]

# %%
app_sample
# Out:
#                                                  App Name  \
# 680082                                        2048 - Dark
# 1302179                           New Year Countdown 2020
# 2209906                    Imágenes de Amistad con Frases
# 187085                                 ExpoMYS - Demo App
# 566226                      TOPZ Frozen Yogurt Metro Deli
# ...                                                   ...
# 1474007                        Virus Wars Taksim İstanbul
# 385002   Euro 2020 | Scorepion | Football Prediction Game
# 1057168                                     Bluetooth RGB
# 386064    VidMedia Downloader - All Video Downloader Free
# 446550                                 Ebony Reigns Songs
#
#                                             App Id                 Category  \
# 680082                    com.parthshukla.game2048                   Puzzle
# 1302179            com.giudicelli.newyearcountdown                Lifestyle
# 2209906       com.cerezapps.Frasesbonitasdeamistad            Communication
# 187085        air.com.mapyourshow.EXPOMYSMobileApp                 Business
# 566226       com.chownow.topzfrozenyogurtmetrodeli             Food & Drink
# ...                                            ...                      ...
# 1474007    com.RotikaGames.VirusWarsTaksimIstanbul                   Action
# 385002                      com.coodehub.scorepion                   Sports
# 1057168               nextprototypes.bluetoothtRGB            Communication
# 386064   snaptubevideodownloader.snadownloadvideos  Video Players & Editors
# 446550                         com.zandanapp.ebony            Music & Audio
#
#          Rating  Rating Count Installs  Minimum Installs  Maximum Installs  \
# 680082      4.2          12.0     500+             500.0               855
# 1302179     0.0           0.0     100+             100.0               137
# 2209906     0.0           0.0      10+              10.0                40
# 187085      0.0           0.0     100+             100.0               102
# 566226      0.0           0.0     100+             100.0               365
# ...         ...           ...      ...               ...               ...
# 1474007     5.0           6.0       5+               5.0                 9
# 385002      4.0          43.0   5,000+            5000.0              9425
# 1057168     3.0          59.0  10,000+           10000.0             41711
# 386064      4.7         517.0  50,000+           50000.0             58230
# 446550      3.0           5.0   1,000+            1000.0              1195
#
#          Free  Price  ...                                  Developer Website  \
# 680082   True    0.0  ...                                                NaN
# 1302179  True    0.0  ...                                                NaN
# 2209906  True    0.0  ...  https://cerezapps.com/imágenes-de-amistad-con-...
# 187085   True    0.0  ...                       https://www.mapyourshow.com/
# 566226   True    0.0  ...                             http://www.chownow.com
# ...       ...    ...  ...                                                ...
# 1474007  True    0.0  ...                                                NaN
# 385002   True    0.0  ...                                                NaN
# 1057168  True    0.0  ...                                                NaN
# 386064   True    0.0  ...                                                NaN
# 446550   True    0.0  ...                                                NaN
#
#                       Developer Email      Released  Last Updated  \
# 680082       parthshukla285@gmail.com   Jul 1, 2020  Jul 09, 2020
# 1302179  patrick.giudicelli@gmail.com  Dec 30, 2017  Nov 26, 2019
# 2209906        contacto@cerezapps.com   Jan 4, 2019  Jan 14, 2019
# 187085        support@mapyourshow.com  Oct 19, 2017  May 21, 2021
# 566226        eng-android@chownow.com   Nov 7, 2016  Feb 19, 2020
# ...                               ...           ...           ...
# 1474007        rotika.games@gmail.com  May 22, 2021  Jun 04, 2021
# 385002             coodehub@gmail.com  Sep 20, 2020  Jun 14, 2021
# 1057168     next.prototypes@gmail.com   Dec 3, 2013  Dec 20, 2014
# 386064     Farhanakausar548@gmail.com  Dec 30, 2020  Mar 24, 2021
# 446550            zandanapp@gmail.com  May 18, 2020  May 19, 2020
#
#         Content Rating                                  Privacy Policy  \
# 680082        Everyone       https://2048-4.flycricket.io/privacy.html
# 1302179       Everyone                                             NaN
# 2209906       Everyone  https://cerezapps.com/politicas-de-privacidad/
# 187085        Everyone   http://www.mapyourshow.com/privacy-policy.cfm
# 566226        Everyone           http://www.chownow.com/privacy-policy
# ...                ...                                             ...
# 1474007           Teen                                             NaN
# 385002        Everyone                                             NaN
# 1057168       Everyone                                             NaN
# 386064        Everyone                                             NaN
# 446550        Everyone                                             NaN
#
#         Ad Supported In App Purchases Editors Choice         Scraped Time
# 680082          True            False          False  2021-06-16 07:19:26
# 1302179         True            False          False  2021-06-15 22:12:27
# 2209906         True            False          False  2021-06-16 11:29:13
# 187085         False            False          False  2021-06-15 23:30:13
# 566226         False            False          False  2021-06-16 05:34:49
# ...              ...              ...            ...                  ...
# 1474007         True            False          False  2021-06-16 00:56:57
# 385002         False            False          False  2021-06-16 02:50:57
# 1057168         True            False          False  2021-06-16 13:13:48
# 386064          True            False          False  2021-06-16 02:51:57
# 446550          True            False          False  2021-06-16 03:47:03
#
# [10000 rows x 24 columns]
